# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('datasets/RawData.csv')

# %%
data
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 0     nfp8122            1      0                   1                     0  \
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1660  nfp8334            7      1                   1                     0
# 1661  nfp8334            8      1                   1                     0
# 1662  nfp8334            9      1                   1                     0
# 1663  nfp8334           10      1                   1                     1
# 1664  nfp8334           11      1                   1                     2
#
# ...

# %%
len(data["ClientID"].unique())
# Out:
# 159

# %%
# Find the duplicate occurrences of ClientID and CycleNumber
duplicate_occurrences = data[data.duplicated(['ClientID', 'CycleNumber'], keep=False)]

# Group the duplicate occurrences by ClientID and CycleNumber and count the occurrences
duplicate_counts = duplicate_occurrences.groupby(['ClientID', 'CycleNumber']).size().reset_index(name='OccurrenceCount')

# Filter the duplicate counts to keep the occurrences with count greater than 1
duplicate_counts = duplicate_counts[duplicate_counts['OccurrenceCount'] > 1]

# Print the duplicate occurrences
if duplicate_counts.empty:
    print("No occurrences with multiple rows found.")
else:
    print("Occurrences with multiple rows:")
    print(duplicate_counts)
# Out:
# Occurrences with multiple rows:
#    ClientID  CycleNumber  OccurrenceCount
# 0   nfp8106            1                2
# 1   nfp8106            2                2
# 2   nfp8106            3                2
# 3   nfp8107            1                2
# 4   nfp8107            2                2
# 5   nfp8107            3                2
# 6   nfp8107            4                2
# 7   nfp8107            5                2
# 8   nfp8107            6                2
# 9   nfp8107            7                2
# 10  nfp8107            8                2
# 11  nfp8109            1                2
# 12  nfp8109            2                2
# 13  nfp8109            3                2
# 14  nfp8114            1                2
# 15  nfp8114            2                2

# %%
to_remove_list = [x for x in duplicate_counts["ClientID"].unique() if x !='nfp8107']
to_remove_list
# Out:
# ['nfp8106', 'nfp8109', 'nfp8114']

# %%
len(data)
# Out:
# 1665

# %%
data = data[~data["ClientID"].isin(to_remove_list)]
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 0     nfp8122            1      0                   1                     0  \
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1644  nfp8334            7      1                   1                     0
# 1645  nfp8334            8      1                   1                     0
# 1646  nfp8334            9      1                   1                     0
# 1647  nfp8334           10      1                   1                     1
# 1648  nfp8334           11      1                   1                     2
#
# ...

# %%
filtered_df = data.groupby('ClientID').filter(lambda x: len(x) > 4)
filtered_df.reset_index(drop=True, inplace=True)

# %%
filtered_df
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 0     nfp8122            1      0                   1                     0  \
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1557  nfp8334            7      1                   1                     0
# 1558  nfp8334            8      1                   1                     0
# 1559  nfp8334            9      1                   1                     0
# 1560  nfp8334           10      1                   1                     1
# 1561  nfp8334           11      1                   1                     2
#
# ...

# %%
len(filtered_df['ClientID'].unique())
# Out:
# 118

# %%
filtered_df[filtered_df["ClientID"]=="nfp8107"]
# Out:
#     ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 45   nfp8107            1      0                   1                     0  \
# 46   nfp8107            2      0                   1                     0
# 47   nfp8107            3      0                   1                     0
# 48   nfp8107            4      0                   1                     0
# 49   nfp8107            5      0                   0                     0
# 50   nfp8107            6      0                   0                     0
# 51   nfp8107            7      0                   1                     0
# 52   nfp8107            8      0                   0                     0
# 470  nfp8107            1      0                   1                     0
# 471  nfp8107            2      0                   1                     0
# 472  nfp8107            3      0                   1                     0
# ...

# %%
# filtered_df.drop(filtered_df.index[470:478], inplace=True)
filtered_df.drop(filtered_df.index[45:53], inplace=True)
filtered_df.reset_index(drop=True, inplace=True)

# %%
filtered_df[filtered_df["ClientID"]=="nfp8107"]
# Out:
#     ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 462  nfp8107            1      0                   1                     0  \
# 463  nfp8107            2      0                   1                     0
# 464  nfp8107            3      0                   1                     0
# 465  nfp8107            4      0                   1                     0
# 466  nfp8107            5      0                   0                     0
# 467  nfp8107            6      0                   0                     0
# 468  nfp8107            7      0                   1                     0
# 469  nfp8107            8      0                   0                     0
#
#      LengthofCycle MeanCycleLength EstimatedDayofOvulation
# 462             28           26.75                      18  \
# 463             26                                      18
# 464             25                                      16
# ...

# %%
filtered_df
# Out:
#      ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory
# 0     nfp8122            1      0                   1                     0  \
# 1     nfp8122            2      0                   1                     0
# 2     nfp8122            3      0                   1                     0
# 3     nfp8122            4      0                   1                     0
# 4     nfp8122            5      0                   1                     0
# ...       ...          ...    ...                 ...                   ...
# 1549  nfp8334            7      1                   1                     0
# 1550  nfp8334            8      1                   1                     0
# 1551  nfp8334            9      1                   1                     0
# 1552  nfp8334           10      1                   1                     1
# 1553  nfp8334           11      1                   1                     2
#
# ...

# %%
filtered_df.to_csv('datasets/FilteredData.csv', index=False)

# %%
filtered_df.set_index('ClientID').T["nfp8107"]
# Out:
# ClientID             nfp8107 nfp8107 nfp8107 nfp8107 nfp8107 nfp8107 nfp8107
# CycleNumber                1       2       3       4       5       6       7  \
# Group                      0       0       0       0       0       0       0
# CycleWithPeakorNot         1       1       1       1       0       0       1
# ReproductiveCategory       0       0       0       0       0       0       0
# LengthofCycle             28      26      25      25      29      29      28
# ...                      ...     ...     ...     ...     ...     ...     ...
# NextpregM                  3
# Spousesame                 1
# SpousesameM                1
# Timeattemptpreg            0
# BMI
#
# ClientID             nfp8107
# CycleNumber                8
# Group                      0
# CycleWithPeakorNot         0
# ReproductiveCategory       0
# LengthofCycle             24
# ...                      ...
# NextpregM
# Spousesame
# SpousesameM
# Timeattemptpreg
# BMI
#
# [79 rows x 8 columns]
